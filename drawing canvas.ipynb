# %%
from IPython.display import HTML

HTML("""
<canvas id="canvas" width="600" height="400" style="border:1px solid #000; touch-action: none;"></canvas>

<script>
let canvas = document.getElementById('canvas');
let ctx = canvas.getContext('2d');
let painting = false;

function startPosition(e) {
    painting = true;
    draw(e);
}
function endPosition() {
    painting = false;
    ctx.beginPath();
}
function draw(e) {
    if (!painting) return;
    let x = e.offsetX;
    let y = e.offsetY;
    ctx.lineWidth = 2;
    ctx.lineCap = 'round';
    ctx.strokeStyle = 'black';
    ctx.lineTo(x, y);
    ctx.stroke();
    ctx.beginPath();
    ctx.moveTo(x, y);
}

// Mouse events
canvas.addEventListener('mousedown', startPosition);
canvas.addEventListener('mouseup', endPosition);
canvas.addEventListener('mousemove', draw);

// Touch or stylus input
canvas.addEventListener('touchstart', (e) => {
    e.preventDefault();
    const rect = canvas.getBoundingClientRect();
    const touch = e.touches[0];
    const x = touch.clientX - rect.left;
    const y = touch.clientY - rect.top;
    painting = true;
    ctx.moveTo(x, y);
});

canvas.addEventListener('touchend', () => {
    painting = false;
    ctx.beginPath();
});

canvas.addEventListener('touchmove', (e) => {
    e.preventDefault();
    if (!painting) return;
    const rect = canvas.getBoundingClientRect();
    const touch = e.touches[0];
    const x = touch.clientX - rect.left;
    const y = touch.clientY - rect.top;
    ctx.lineTo(x, y);
    ctx.stroke();
    ctx.beginPath();
    ctx.moveTo(x, y);
});
</script>
""")
# Out:
# <canvas id="canvas" width="600" height="400" style="border:1px solid #000; touch-action: none;"></canvas>
#
# <script>
# let canvas = document.getElementById('canvas');
# let ctx = canvas.getContext('2d');
# let painting = false;
#
# function startPosition(e) {
#     painting = true;
#     draw(e);
# }
# function endPosition() {
#     painting = false;
#     ctx.beginPath();
# }
# function draw(e) {
#     if (!painting) return;
#     let x = e.offsetX;
#     let y = e.offsetY;
#     ctx.lineWidth = 2;
#     ctx.lineCap = 'round';
#     ctx.strokeStyle = 'black';
#     ctx.lineTo(x, y);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.moveTo(x, y);
# }
#
# // Mouse events
# canvas.addEventListener('mousedown', startPosition);
# canvas.addEventListener('mouseup', endPosition);
# canvas.addEventListener('mousemove', draw);
#
# // Touch or stylus input
# canvas.addEventListener('touchstart', (e) => {
#     e.preventDefault();
#     const rect = canvas.getBoundingClientRect();
#     const touch = e.touches[0];
#     const x = touch.clientX - rect.left;
#     const y = touch.clientY - rect.top;
#     painting = true;
#     ctx.moveTo(x, y);
# });
#
# canvas.addEventListener('touchend', () => {
#     painting = false;
#     ctx.beginPath();
# });
#
# canvas.addEventListener('touchmove', (e) => {
#     e.preventDefault();
#     if (!painting) return;
#     const rect = canvas.getBoundingClientRect();
#     const touch = e.touches[0];
#     const x = touch.clientX - rect.left;
#     const y = touch.clientY - rect.top;
#     ctx.lineTo(x, y);
#     ctx.stroke();
#     ctx.beginPath();
#     ctx.moveTo(x, y);
# });
# </script>
